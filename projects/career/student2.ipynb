# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/aviral/Documents/programming/datas/student2.csv')
data.head()
# Out:
#    Database Fundamentals  Computer Architecture  \
# 0                      9                      1
# 1                      9                      2
# 2                      9                      3
# 3                      9                      5
# 4                      9                      6
#
#    Distributed Computing Systems  Cyber Security  Networking  \
# 0                              1               1           1
# 1                              1               1           1
# 2                              1               1           1
# 3                              1               1           1
# 4                              1               1           1
#
#    Software Development  Programming Skills  Project Management  \
# 0                     1                   1                   1
# 1                     1                   1                   1
# 2                     1                   1                   1
# ...

# %%
features = ['Database Fundamentals','Computer Architecture','Distributed Computing Systems','Cyber Security','Networking','Software Development','Programming Skills','Project Management','Computer Forensics Fundamentals','Technical Communication','AI ML','Software Engineering','Business Analysis','Communication skills','Data Science','Troubleshooting skills','Graphics Designing']
x = data[features]
y = data['Role']

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,train_y,test_y = train_test_split(x,y)

# %%
from lazypredict.Supervised import LazyClassifier

model = LazyClassifier()
models, predictions = model.fit(train_x,test_x,train_y,test_y)
models.head(60)
# Out:
#  34%|███▍      | 10/29 [00:03<00:05,  3.66it/s]

# %%
from sklearn.svm import SVC

SVM = SVC()
SVM.fit(train_x,train_y)
# Out:
# SVC()

# %%
data.head()
# Out:
#    Database Fundamentals  Computer Architecture  \
# 0                      9                      1
# 1                      9                      2
# 2                      9                      3
# 3                      9                      5
# 4                      9                      6
#
#    Distributed Computing Systems  Cyber Security  Networking  \
# 0                              1               1           1
# 1                              1               1           1
# 2                              1               1           1
# 3                              1               1           1
# 4                              1               1           1
#
#    Software Development  Programming Skills  Project Management  \
# 0                     1                   1                   1
# 1                     1                   1                   1
# 2                     1                   1                   1
# ...

# %%
SVM.predict([[8,1,1,4,1,1,6,5,1,7,9,1,6,7,9,1,1]])
# Out:
# array(['AI ML Specialist'], dtype=object)

# %%
prediction = SVM.predict(test_x)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(test_y, prediction)
# Out:
# 0.9995642701525055

# %%
import pickle

# %%
with open('model2_pkl', 'wb') as files:
    pickle.dump(SVM, files)
